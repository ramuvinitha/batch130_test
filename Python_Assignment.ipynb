# %% [markdown]
# Mean

# %%
num_list = [21, 11, 19, 3,11,5]
# FInd sum of the numbers
num_sum = sum(num_list)
#divide the sum with length of the list
mean = num_sum / len(num_list)
print(num_list)
print("Mean of the above list of numbers is: " + str(round(mean,2)))
# Out:
# [21, 11, 19, 3, 11, 5]
# Mean of the above list of numbers is: 11.67

# %% [markdown]
# Median

# %%
# Python program to print
# median of elements

# list of elements to calculate median
n_num = [1, 2, 3, 4, 5]
n = len(n_num)
n_num.sort()

if n % 2 == 0:
	median1 = n_num[n//2]
	median2 = n_num[n//2 - 1]
	median = (median1 + median2)/2
else:
	median = n_num[n//2]
print("Median is: " + str(median))
# Out:
# Median is: 3

# %% [markdown]
# IQR

# %%
import numpy as np

# %%
#First Quartile
Q1=np.median(n_num[:4])
print("Q1 is:",Q1)
##Third Quartile
Q3=np.median(n_num[4:])
print("Q3 is:",Q3)
##IQR
IQR=Q3-Q1
print("IQR is",IQR)
# Out:
# Q1 is: 2.5
# Q3 is: 5.0
# IQR is 2.5

# %% [markdown]
# Rolling a dice

# %%
import random
count=[0,0,0,0,0,0]
for i in range(10000):
  count[random.randint(0,5)]+=1
  for i in range(6):
    print("value %d happened %d times" %(i+1,count[i]))
# Out:
# Streaming output truncated to the last 5000 lines.
# value 5 happened 1541 times
# value 6 happened 1509 times
# value 1 happened 1574 times
# value 2 happened 1546 times
# value 3 happened 1503 times
# value 4 happened 1494 times
# value 5 happened 1541 times
# value 6 happened 1510 times
# value 1 happened 1574 times
# value 2 happened 1546 times
# value 3 happened 1503 times
# value 4 happened 1494 times
# value 5 happened 1542 times
# value 6 happened 1510 times
# value 1 happened 1574 times
# value 2 happened 1546 times
# value 3 happened 1503 times
# value 4 happened 1494 times
# value 5 happened 1543 times
# value 6 happened 1510 times
# value 1 happened 1574 times
# value 2 happened 1546 times
# value 3 happened 1503 times
# value 4 happened 1495 times
# value 5 happened 1543 times
# value 6 happened 1510 times
# value 1 happened 1574 times
# value 2 happened 1546 times
# value 3 happened 1503 times
# value 4 happened 1495 times
# value 5 happened 1543 times
# value 6 happened 1511 times
# value 1 happened 1574 times
# value 2 happened 1546 times
# value 3 happened 1503 times
# value 4 happened 1495 times
# value 5 happened 1543 times
# value 6 happened 1512 times
# value 1 happened 1574 times
# value 2 happened 1546 times
# value 3 happened 1503 times
# value 4 happened 1495 times
# value 5 happened 1544 times
# value 6 happened 1512 times
# value 1 happened 1574 times
# value 2 happened 1546 times
# value 3 happened 1503 times
# value 4 happened 1495 times
# value 5 happened 1544 times
# value 6 happened 1513 times
# value 1 happened 1574 times
# value 2 happened 1546 times
# value 3 happened 1503 times
# value 4 happened 1495 times
# value 5 happened 1544 times
# value 6 happened 1514 times
# value 1 happened 1575 times
# value 2 happened 1546 times
# value 3 happened 1503 times
# value 4 happened 1495 times
# value 5 happened 1544 times
# value 6 happened 1514 times
# value 1 happened 1575 times
# value 2 happened 1546 times
# value 3 happened 1503 times
# value 4 happened 1495 times
# value 5 happened 1545 times
# value 6 happened 1514 times
# value 1 happened 1575 times
# value 2 happened 1546 times
# value 3 happened 1504 times
# value 4 happened 1495 times
# value 5 happened 1545 times
# value 6 happened 1514 times
# value 1 happened 1575 times
# value 2 happened 1546 times
# value 3 happened 1504 times
# value 4 happened 1495 times
# value 5 happened 1545 times
# value 6 happened 1515 times
# value 1 happened 1575 times
# value 2 happened 1546 times
# value 3 happened 1504 times
# value 4 happened 1495 times
# value 5 happened 1545 times
# value 6 happened 1516 times
# value 1 happened 1575 times
# value 2 happened 1546 times
# value 3 happened 1504 times
# value 4 happened 1496 times
# value 5 happened 1545 times
# value 6 happened 1516 times
# value 1 happened 1575 times
# value 2 happened 1546 times
# value 3 happened 1504 times
# value 4 happened 1496 times
# value 5 happened 1545 times
# value 6 happened 1517 times
# value 1 happened 1576 times
# value 2 happened 1546 times
# value 3 happened 1504 times
# value 4 happened 1496 times
# value 5 happened 1545 times
# value 6 happened 1517 times
# value 1 happened 1576 times
# value 2 happened 1547 times
# value 3 happened 1504 times
# value 4 happened 1496 times
# value 5 happened 1545 times
# value 6 happened 1517 times
# value 1 happened 1576 times
# value 2 happened 1548 times
# value 3 happened 1504 times
# value 4 happened 1496 times
# value 5 happened 1545 times
# value 6 happened 1517 times
# value 1 happened 1576 times
# value 2 happened 1548 times
# value 3 happened 1504 times
# value 4 happened 1496 times
# value 5 happened 1545 times
# value 6 happened 1518 times
# value 1 happened 1576 times
# value 2 happened 1548 times
# value 3 happened 1504 times
# value 4 happened 1496 times
# value 5 happened 1545 times
# value 6 happened 1519 times
# value 1 happened 1577 times
# value 2 happened 1548 times
# value 3 happened 1504 times
# value 4 happened 1496 times
# value 5 happened 1545 times
# value 6 happened 1519 times
# value 1 happened 1577 times
# value 2 happened 1548 times
# value 3 happened 1504 times
# value 4 happened 1497 times
# value 5 happened 1545 times
# value 6 happened 1519 times
# value 1 happened 1577 times
# value 2 happened 1548 times
# value 3 happened 1504 times
# value 4 happened 1497 times
# value 5 happened 1545 times
# value 6 happened 1520 times
# value 1 happened 1577 times
# value 2 happened 1548 times
# value 3 happened 1504 times
# value 4 happened 1497 times
# value 5 happened 1545 times
# value 6 happened 1521 times
# value 1 happened 1577 times
# value 2 happened 1548 times
# value 3 happened 1504 times
# value 4 happened 1497 times
# value 5 happened 1546 times
# value 6 happened 1521 times
# value 1 happened 1577 times
# value 2 happened 1548 times
# value 3 happened 1504 times
# value 4 happened 1497 times
# value 5 happened 1546 times
# value 6 happened 1522 times
# value 1 happened 1577 times
# value 2 happened 1548 times
# value 3 happened 1504 times
# value 4 happened 1497 times
# value 5 happened 1546 times
# value 6 happened 1523 times
# value 1 happened 1577 times
# value 2 happened 1549 times
# value 3 happened 1504 times
# value 4 happened 1497 times
# value 5 happened 1546 times
# value 6 happened 1523 times
# value 1 happened 1577 times
# value 2 happened 1549 times
# value 3 happened 1505 times
# value 4 happened 1497 times
# value 5 happened 1546 times
# value 6 happened 1523 times
# value 1 happened 1577 times
# value 2 happened 1549 times
# value 3 happened 1506 times
# value 4 happened 1497 times
# value 5 happened 1546 times
# value 6 happened 1523 times
# value 1 happened 1577 times
# value 2 happened 1549 times
# value 3 happened 1507 times
# value 4 happened 1497 times
# value 5 happened 1546 times
# value 6 happened 1523 times
# value 1 happened 1577 times
# value 2 happened 1549 times
# value 3 happened 1507 times
# value 4 happened 1498 times
# value 5 happened 1546 times
# value 6 happened 1523 times
# value 1 happened 1577 times
# value 2 happened 1549 times
# value 3 happened 1507 times
# value 4 happened 1499 times
# value 5 happened 1546 times
# value 6 happened 1523 times
# value 1 happened 1577 times
# value 2 happened 1549 times
# value 3 happened 1507 times
# value 4 happened 1499 times
# value 5 happened 1546 times
# value 6 happened 1524 times
# value 1 happened 1578 times
# value 2 happened 1549 times
# value 3 happened 1507 times
# value 4 happened 1499 times
# value 5 happened 1546 times
# value 6 happened 1524 times
# value 1 happened 1578 times
# value 2 happened 1549 times
# value 3 happened 1507 times
# value 4 happened 1500 times
# value 5 happened 1546 times
# value 6 happened 1524 times
# value 1 happened 1578 times
# value 2 happened 1550 times
# value 3 happened 1507 times
# value 4 happened 1500 times
# value 5 happened 1546 times
# value 6 happened 1524 times
# value 1 happened 1578 times
# value 2 happened 1550 times
# value 3 happened 1507 times
# value 4 happened 1500 times
# value 5 happened 1547 times
# value 6 happened 1524 times
# value 1 happened 1578 times
# value 2 happened 1550 times
# value 3 happened 1507 times
# value 4 happened 1500 times
# value 5 happened 1548 times
# value 6 happened 1524 times
# value 1 happened 1578 times
# value 2 happened 1550 times
# value 3 happened 1507 times
# value 4 happened 1500 times
# value 5 happened 1548 times
# value 6 happened 1525 times
# value 1 happened 1579 times
# value 2 happened 1550 times
# value 3 happened 1507 times
# value 4 happened 1500 times
# value 5 happened 1548 times
# value 6 happened 1525 times
# value 1 happened 1579 times
# value 2 happened 1550 times
# value 3 happened 1507 times
# value 4 happened 1500 times
# value 5 happened 1549 times
# value 6 happened 1525 times
# value 1 happened 1579 times
# value 2 happened 1550 times
# value 3 happened 1507 times
# value 4 happened 1501 times
# value 5 happened 1549 times
# value 6 happened 1525 times
# value 1 happened 1580 times
# value 2 happened 1550 times
# value 3 happened 1507 times
# value 4 happened 1501 times
# value 5 happened 1549 times
# value 6 happened 1525 times
# value 1 happened 1580 times
# value 2 happened 1551 times
# value 3 happened 1507 times
# value 4 happened 1501 times
# value 5 happened 1549 times
# value 6 happened 1525 times
# value 1 happened 1581 times
# value 2 happened 1551 times
# value 3 happened 1507 times
# value 4 happened 1501 times
# value 5 happened 1549 times
# value 6 happened 1525 times
# value 1 happened 1582 times
# value 2 happened 1551 times
# value 3 happened 1507 times
# value 4 happened 1501 times
# value 5 happened 1549 times
# value 6 happened 1525 times
# value 1 happened 1582 times
# value 2 happened 1551 times
# value 3 happened 1507 times
# value 4 happened 1501 times
# value 5 happened 1549 times
# value 6 happened 1526 times
# value 1 happened 1582 times
# value 2 happened 1551 times
# value 3 happened 1508 times
# value 4 happened 1501 times
# value 5 happened 1549 times
# value 6 happened 1526 times
# value 1 happened 1582 times
# value 2 happened 1551 times
# value 3 happened 1509 times
# value 4 happened 1501 times
# value 5 happened 1549 times
# value 6 happened 1526 times
# value 1 happened 1582 times
# value 2 happened 1552 times
# value 3 happened 1509 times
# value 4 happened 1501 times
# value 5 happened 1549 times
# value 6 happened 1526 times
# value 1 happened 1582 times
# value 2 happened 1552 times
# value 3 happened 1509 times
# value 4 happened 1501 times
# value 5 happened 1550 times
# value 6 happened 1526 times
# value 1 happened 1582 times
# value 2 happened 1552 times
# value 3 happened 1509 times
# value 4 happened 1501 times
# value 5 happened 1550 times
# value 6 happened 1527 times
# value 1 happened 1582 times
# value 2 happened 1552 times
# value 3 happened 1509 times
# value 4 happened 1501 times
# value 5 happened 1551 times
# value 6 happened 1527 times
# value 1 happened 1582 times
# value 2 happened 1552 times
# value 3 happened 1509 times
# value 4 happened 1501 times
# value 5 happened 1552 times
# value 6 happened 1527 times
# value 1 happened 1582 times
# value 2 happened 1552 times
# value 3 happened 1510 times
# value 4 happened 1501 times
# value 5 happened 1552 times
# value 6 happened 1527 times
# value 1 happened 1582 times
# value 2 happened 1552 times
# value 3 happened 1510 times
# value 4 happened 1502 times
# value 5 happened 1552 times
# value 6 happened 1527 times
# value 1 happened 1583 times
# value 2 happened 1552 times
# value 3 happened 1510 times
# value 4 happened 1502 times
# value 5 happened 1552 times
# value 6 happened 1527 times
# value 1 happened 1583 times
# value 2 happened 1552 times
# value 3 happened 1510 times
# value 4 happened 1502 times
# value 5 happened 1552 times
# value 6 happened 1528 times
# value 1 happened 1583 times
# value 2 happened 1553 times
# value 3 happened 1510 times
# value 4 happened 1502 times
# value 5 happened 1552 times
# value 6 happened 1528 times
# value 1 happened 1583 times
# value 2 happened 1553 times
# value 3 happened 1510 times
# value 4 happened 1502 times
# value 5 happened 1553 times
# value 6 happened 1528 times
# value 1 happened 1583 times
# value 2 happened 1553 times
# value 3 happened 1511 times
# value 4 happened 1502 times
# value 5 happened 1553 times
# value 6 happened 1528 times
# value 1 happened 1583 times
# value 2 happened 1553 times
# value 3 happened 1511 times
# value 4 happened 1503 times
# value 5 happened 1553 times
# value 6 happened 1528 times
# value 1 happened 1583 times
# value 2 happened 1554 times
# value 3 happened 1511 times
# value 4 happened 1503 times
# value 5 happened 1553 times
# value 6 happened 1528 times
# value 1 happened 1583 times
# value 2 happened 1555 times
# value 3 happened 1511 times
# value 4 happened 1503 times
# value 5 happened 1553 times
# value 6 happened 1528 times
# value 1 happened 1583 times
# value 2 happened 1555 times
# value 3 happened 1512 times
# value 4 happened 1503 times
# value 5 happened 1553 times
# value 6 happened 1528 times
# value 1 happened 1583 times
# value 2 happened 1555 times
# value 3 happened 1512 times
# value 4 happened 1503 times
# value 5 happened 1554 times
# value 6 happened 1528 times
# value 1 happened 1583 times
# value 2 happened 1555 times
# value 3 happened 1513 times
# value 4 happened 1503 times
# value 5 happened 1554 times
# value 6 happened 1528 times
# value 1 happened 1583 times
# value 2 happened 1555 times
# value 3 happened 1513 times
# value 4 happened 1503 times
# value 5 happened 1555 times
# value 6 happened 1528 times
# value 1 happened 1583 times
# value 2 happened 1556 times
# value 3 happened 1513 times
# value 4 happened 1503 times
# value 5 happened 1555 times
# value 6 happened 1528 times
# value 1 happened 1583 times
# value 2 happened 1556 times
# value 3 happened 1513 times
# value 4 happened 1503 times
# value 5 happened 1555 times
# value 6 happened 1529 times
# value 1 happened 1583 times
# value 2 happened 1556 times
# value 3 happened 1514 times
# value 4 happened 1503 times
# value 5 happened 1555 times
# value 6 happened 1529 times
# value 1 happened 1583 times
# value 2 happened 1556 times
# value 3 happened 1514 times
# value 4 happened 1503 times
# value 5 happened 1555 times
# value 6 happened 1530 times
# value 1 happened 1584 times
# value 2 happened 1556 times
# value 3 happened 1514 times
# value 4 happened 1503 times
# value 5 happened 1555 times
# value 6 happened 1530 times
# value 1 happened 1584 times
# value 2 happened 1556 times
# value 3 happened 1514 times
# value 4 happened 1504 times
# value 5 happened 1555 times
# value 6 happened 1530 times
# value 1 happened 1584 times
# value 2 happened 1557 times
# value 3 happened 1514 times
# value 4 happened 1504 times
# value 5 happened 1555 times
# value 6 happened 1530 times
# value 1 happened 1584 times
# value 2 happened 1557 times
# value 3 happened 1514 times
# value 4 happened 1505 times
# value 5 happened 1555 times
# value 6 happened 1530 times
# value 1 happened 1585 times
# value 2 happened 1557 times
# value 3 happened 1514 times
# value 4 happened 1505 times
# value 5 happened 1555 times
# value 6 happened 1530 times
# value 1 happened 1585 times
# value 2 happened 1557 times
# value 3 happened 1514 times
# value 4 happened 1505 times
# value 5 happened 1556 times
# value 6 happened 1530 times
# value 1 happened 1585 times
# value 2 happened 1557 times
# value 3 happened 1515 times
# value 4 happened 1505 times
# value 5 happened 1556 times
# value 6 happened 1530 times
# value 1 happened 1585 times
# value 2 happened 1558 times
# value 3 happened 1515 times
# value 4 happened 1505 times
# value 5 happened 1556 times
# value 6 happened 1530 times
# value 1 happened 1586 times
# value 2 happened 1558 times
# value 3 happened 1515 times
# value 4 happened 1505 times
# value 5 happened 1556 times
# value 6 happened 1530 times
# value 1 happened 1586 times
# value 2 happened 1559 times
# value 3 happened 1515 times
# value 4 happened 1505 times
# value 5 happened 1556 times
# value 6 happened 1530 times
# value 1 happened 1586 times
# value 2 happened 1559 times
# value 3 happened 1515 times
# value 4 happened 1506 times
# value 5 happened 1556 times
# value 6 happened 1530 times
# value 1 happened 1587 times
# value 2 happened 1559 times
# value 3 happened 1515 times
# value 4 happened 1506 times
# value 5 happened 1556 times
# value 6 happened 1530 times
# value 1 happened 1587 times
# value 2 happened 1559 times
# value 3 happened 1515 times
# value 4 happened 1506 times
# value 5 happened 1557 times
# value 6 happened 1530 times
# value 1 happened 1588 times
# value 2 happened 1559 times
# value 3 happened 1515 times
# value 4 happened 1506 times
# value 5 happened 1557 times
# value 6 happened 1530 times
# value 1 happened 1588 times
# value 2 happened 1559 times
# value 3 happened 1515 times
# value 4 happened 1506 times
# value 5 happened 1557 times
# value 6 happened 1531 times
# value 1 happened 1588 times
# value 2 happened 1559 times
# value 3 happened 1515 times
# value 4 happened 1507 times
# value 5 happened 1557 times
# value 6 happened 1531 times
# value 1 happened 1589 times
# value 2 happened 1559 times
# value 3 happened 1515 times
# value 4 happened 1507 times
# value 5 happened 1557 times
# value 6 happened 1531 times
# value 1 happened 1589 times
# value 2 happened 1559 times
# value 3 happened 1515 times
# value 4 happened 1507 times
# value 5 happened 1557 times
# value 6 happened 1532 times
# value 1 happened 1590 times
# value 2 happened 1559 times
# value 3 happened 1515 times
# value 4 happened 1507 times
# value 5 happened 1557 times
# value 6 happened 1532 times
# value 1 happened 1590 times
# value 2 happened 1559 times
# value 3 happened 1515 times
# value 4 happened 1507 times
# value 5 happened 1557 times
# value 6 happened 1533 times
# value 1 happened 1590 times
# value 2 happened 1559 times
# value 3 happened 1515 times
# value 4 happened 1508 times
# value 5 happened 1557 times
# value 6 happened 1533 times
# value 1 happened 1590 times
# value 2 happened 1559 times
# value 3 happened 1515 times
# value 4 happened 1508 times
# value 5 happened 1558 times
# value 6 happened 1533 times
# value 1 happened 1590 times
# value 2 happened 1559 times
# value 3 happened 1516 times
# value 4 happened 1508 times
# value 5 happened 1558 times
# value 6 happened 1533 times
# value 1 happened 1590 times
# value 2 happened 1559 times
# value 3 happened 1516 times
# value 4 happened 1508 times
# value 5 happened 1559 times
# value 6 happened 1533 times
# value 1 happened 1590 times
# value 2 happened 1559 times
# value 3 happened 1517 times
# value 4 happened 1508 times
# value 5 happened 1559 times
# value 6 happened 1533 times
# value 1 happened 1590 times
# value 2 happened 1559 times
# value 3 happened 1518 times
# value 4 happened 1508 times
# value 5 happened 1559 times
# value 6 happened 1533 times
# value 1 happened 1590 times
# value 2 happened 1559 times
# value 3 happened 1518 times
# value 4 happened 1508 times
# value 5 happened 1559 times
# value 6 happened 1534 times
# value 1 happened 1590 times
# value 2 happened 1559 times
# value 3 happened 1519 times
# value 4 happened 1508 times
# value 5 happened 1559 times
# value 6 happened 1534 times
# value 1 happened 1590 times
# value 2 happened 1559 times
# value 3 happened 1519 times
# value 4 happened 1509 times
# value 5 happened 1559 times
# value 6 happened 1534 times
# value 1 happened 1591 times
# value 2 happened 1559 times
# value 3 happened 1519 times
# value 4 happened 1509 times
# value 5 happened 1559 times
# value 6 happened 1534 times
# value 1 happened 1592 times
# value 2 happened 1559 times
# value 3 happened 1519 times
# value 4 happened 1509 times
# value 5 happened 1559 times
# value 6 happened 1534 times
# value 1 happened 1592 times
# value 2 happened 1559 times
# value 3 happened 1519 times
# value 4 happened 1510 times
# value 5 happened 1559 times
# value 6 happened 1534 times
# value 1 happened 1592 times
# value 2 happened 1559 times
# value 3 happened 1520 times
# value 4 happened 1510 times
# value 5 happened 1559 times
# value 6 happened 1534 times
# value 1 happened 1593 times
# value 2 happened 1559 times
# value 3 happened 1520 times
# value 4 happened 1510 times
# value 5 happened 1559 times
# value 6 happened 1534 times
# value 1 happened 1593 times
# value 2 happened 1559 times
# value 3 happened 1520 times
# value 4 happened 1510 times
# value 5 happened 1560 times
# value 6 happened 1534 times
# value 1 happened 1593 times
# value 2 happened 1559 times
# value 3 happened 1521 times
# value 4 happened 1510 times
# value 5 happened 1560 times
# value 6 happened 1534 times
# value 1 happened 1593 times
# value 2 happened 1559 times
# value 3 happened 1522 times
# value 4 happened 1510 times
# value 5 happened 1560 times
# value 6 happened 1534 times
# value 1 happened 1593 times
# value 2 happened 1559 times
# value 3 happened 1522 times
# value 4 happened 1510 times
# value 5 happened 1561 times
# value 6 happened 1534 times
# value 1 happened 1593 times
# value 2 happened 1559 times
# value 3 happened 1522 times
# value 4 happened 1510 times
# value 5 happened 1562 times
# value 6 happened 1534 times
# value 1 happened 1593 times
# value 2 happened 1559 times
# value 3 happened 1522 times
# value 4 happened 1510 times
# value 5 happened 1562 times
# value 6 happened 1535 times
# value 1 happened 1593 times
# value 2 happened 1559 times
# value 3 happened 1522 times
# value 4 happened 1510 times
# value 5 happened 1563 times
# value 6 happened 1535 times
# value 1 happened 1593 times
# value 2 happened 1560 times
# value 3 happened 1522 times
# value 4 happened 1510 times
# value 5 happened 1563 times
# value 6 happened 1535 times
# value 1 happened 1593 times
# value 2 happened 1560 times
# value 3 happened 1522 times
# value 4 happened 1510 times
# value 5 happened 1563 times
# value 6 happened 1536 times
# value 1 happened 1594 times
# value 2 happened 1560 times
# value 3 happened 1522 times
# value 4 happened 1510 times
# value 5 happened 1563 times
# value 6 happened 1536 times
# value 1 happened 1594 times
# value 2 happened 1561 times
# value 3 happened 1522 times
# value 4 happened 1510 times
# value 5 happened 1563 times
# value 6 happened 1536 times
# value 1 happened 1594 times
# value 2 happened 1561 times
# value 3 happened 1523 times
# value 4 happened 1510 times
# value 5 happened 1563 times
# value 6 happened 1536 times
# value 1 happened 1594 times
# value 2 happened 1561 times
# value 3 happened 1523 times
# value 4 happened 1511 times
# value 5 happened 1563 times
# value 6 happened 1536 times
# value 1 happened 1594 times
# value 2 happened 1561 times
# value 3 happened 1523 times
# value 4 happened 1511 times
# value 5 happened 1563 times
# value 6 happened 1537 times
# value 1 happened 1595 times
# value 2 happened 1561 times
# value 3 happened 1523 times
# value 4 happened 1511 times
# value 5 happened 1563 times
# value 6 happened 1537 times
# value 1 happened 1595 times
# value 2 happened 1561 times
# value 3 happened 1523 times
# value 4 happened 1511 times
# value 5 happened 1563 times
# value 6 happened 1538 times
# value 1 happened 1595 times
# value 2 happened 1561 times
# value 3 happened 1523 times
# value 4 happened 1512 times
# value 5 happened 1563 times
# value 6 happened 1538 times
# value 1 happened 1595 times
# value 2 happened 1561 times
# value 3 happened 1523 times
# value 4 happened 1512 times
# value 5 happened 1563 times
# value 6 happened 1539 times
# value 1 happened 1595 times
# value 2 happened 1561 times
# value 3 happened 1524 times
# value 4 happened 1512 times
# value 5 happened 1563 times
# value 6 happened 1539 times
# value 1 happened 1596 times
# value 2 happened 1561 times
# value 3 happened 1524 times
# value 4 happened 1512 times
# value 5 happened 1563 times
# value 6 happened 1539 times
# value 1 happened 1596 times
# value 2 happened 1561 times
# value 3 happened 1525 times
# value 4 happened 1512 times
# value 5 happened 1563 times
# value 6 happened 1539 times
# value 1 happened 1596 times
# value 2 happened 1561 times
# value 3 happened 1525 times
# value 4 happened 1512 times
# value 5 happened 1564 times
# value 6 happened 1539 times
# value 1 happened 1596 times
# value 2 happened 1561 times
# value 3 happened 1525 times
# value 4 happened 1513 times
# value 5 happened 1564 times
# value 6 happened 1539 times
# value 1 happened 1596 times
# value 2 happened 1561 times
# value 3 happened 1526 times
# value 4 happened 1513 times
# value 5 happened 1564 times
# value 6 happened 1539 times
# value 1 happened 1596 times
# value 2 happened 1561 times
# value 3 happened 1527 times
# value 4 happened 1513 times
# value 5 happened 1564 times
# value 6 happened 1539 times
# value 1 happened 1597 times
# value 2 happened 1561 times
# value 3 happened 1527 times
# value 4 happened 1513 times
# value 5 happened 1564 times
# value 6 happened 1539 times
# value 1 happened 1597 times
# value 2 happened 1561 times
# value 3 happened 1527 times
# value 4 happened 1513 times
# value 5 happened 1564 times
# value 6 happened 1540 times
# value 1 happened 1597 times
# value 2 happened 1561 times
# value 3 happened 1527 times
# value 4 happened 1513 times
# value 5 happened 1564 times
# value 6 happened 1541 times
# value 1 happened 1597 times
# value 2 happened 1561 times
# value 3 happened 1527 times
# value 4 happened 1514 times
# value 5 happened 1564 times
# value 6 happened 1541 times
# value 1 happened 1597 times
# value 2 happened 1561 times
# value 3 happened 1527 times
# value 4 happened 1514 times
# value 5 happened 1564 times
# value 6 happened 1542 times
# value 1 happened 1598 times
# value 2 happened 1561 times
# value 3 happened 1527 times
# value 4 happened 1514 times
# value 5 happened 1564 times
# value 6 happened 1542 times
# value 1 happened 1598 times
# value 2 happened 1561 times
# value 3 happened 1527 times
# value 4 happened 1514 times
# value 5 happened 1565 times
# value 6 happened 1542 times
# value 1 happened 1598 times
# value 2 happened 1561 times
# value 3 happened 1527 times
# value 4 happened 1514 times
# value 5 happened 1566 times
# value 6 happened 1542 times
# value 1 happened 1598 times
# value 2 happened 1561 times
# value 3 happened 1527 times
# value 4 happened 1514 times
# value 5 happened 1567 times
# value 6 happened 1542 times
# value 1 happened 1598 times
# value 2 happened 1561 times
# value 3 happened 1527 times
# value 4 happened 1514 times
# value 5 happened 1568 times
# value 6 happened 1542 times
# value 1 happened 1599 times
# value 2 happened 1561 times
# value 3 happened 1527 times
# value 4 happened 1514 times
# value 5 happened 1568 times
# value 6 happened 1542 times
# value 1 happened 1599 times
# value 2 happened 1561 times
# value 3 happened 1527 times
# value 4 happened 1514 times
# value 5 happened 1569 times
# value 6 happened 1542 times
# value 1 happened 1599 times
# value 2 happened 1561 times
# value 3 happened 1527 times
# value 4 happened 1514 times
# value 5 happened 1569 times
# value 6 happened 1543 times
# value 1 happened 1599 times
# value 2 happened 1561 times
# value 3 happened 1527 times
# value 4 happened 1514 times
# value 5 happened 1570 times
# value 6 happened 1543 times
# value 1 happened 1599 times
# value 2 happened 1561 times
# value 3 happened 1527 times
# value 4 happened 1514 times
# value 5 happened 1571 times
# value 6 happened 1543 times
# value 1 happened 1599 times
# value 2 happened 1561 times
# value 3 happened 1527 times
# value 4 happened 1515 times
# value 5 happened 1571 times
# value 6 happened 1543 times
# value 1 happened 1599 times
# value 2 happened 1561 times
# value 3 happened 1527 times
# value 4 happened 1515 times
# value 5 happened 1571 times
# value 6 happened 1544 times
# value 1 happened 1599 times
# value 2 happened 1561 times
# value 3 happened 1527 times
# value 4 happened 1515 times
# value 5 happened 1572 times
# value 6 happened 1544 times
# value 1 happened 1599 times
# value 2 happened 1562 times
# value 3 happened 1527 times
# value 4 happened 1515 times
# value 5 happened 1572 times
# value 6 happened 1544 times
# value 1 happened 1599 times
# value 2 happened 1562 times
# value 3 happened 1527 times
# value 4 happened 1516 times
# value 5 happened 1572 times
# value 6 happened 1544 times
# value 1 happened 1599 times
# value 2 happened 1562 times
# value 3 happened 1527 times
# value 4 happened 1517 times
# value 5 happened 1572 times
# value 6 happened 1544 times
# value 1 happened 1599 times
# value 2 happened 1562 times
# value 3 happened 1528 times
# value 4 happened 1517 times
# value 5 happened 1572 times
# value 6 happened 1544 times
# value 1 happened 1599 times
# value 2 happened 1562 times
# value 3 happened 1528 times
# value 4 happened 1517 times
# value 5 happened 1572 times
# value 6 happened 1545 times
# value 1 happened 1599 times
# value 2 happened 1562 times
# value 3 happened 1528 times
# value 4 happened 1517 times
# value 5 happened 1572 times
# value 6 happened 1546 times
# value 1 happened 1599 times
# value 2 happened 1562 times
# value 3 happened 1529 times
# value 4 happened 1517 times
# value 5 happened 1572 times
# value 6 happened 1546 times
# value 1 happened 1599 times
# value 2 happened 1563 times
# value 3 happened 1529 times
# value 4 happened 1517 times
# value 5 happened 1572 times
# value 6 happened 1546 times
# value 1 happened 1599 times
# value 2 happened 1563 times
# value 3 happened 1529 times
# value 4 happened 1517 times
# value 5 happened 1572 times
# value 6 happened 1547 times
# value 1 happened 1599 times
# value 2 happened 1563 times
# value 3 happened 1529 times
# value 4 happened 1518 times
# value 5 happened 1572 times
# value 6 happened 1547 times
# value 1 happened 1599 times
# value 2 happened 1563 times
# value 3 happened 1529 times
# value 4 happened 1519 times
# value 5 happened 1572 times
# value 6 happened 1547 times
# value 1 happened 1599 times
# value 2 happened 1563 times
# value 3 happened 1530 times
# value 4 happened 1519 times
# value 5 happened 1572 times
# value 6 happened 1547 times
# value 1 happened 1599 times
# value 2 happened 1564 times
# value 3 happened 1530 times
# value 4 happened 1519 times
# value 5 happened 1572 times
# value 6 happened 1547 times
# value 1 happened 1599 times
# value 2 happened 1564 times
# value 3 happened 1530 times
# value 4 happened 1519 times
# value 5 happened 1573 times
# value 6 happened 1547 times
# value 1 happened 1599 times
# value 2 happened 1564 times
# value 3 happened 1530 times
# value 4 happened 1519 times
# value 5 happened 1573 times
# value 6 happened 1548 times
# value 1 happened 1599 times
# value 2 happened 1564 times
# value 3 happened 1531 times
# value 4 happened 1519 times
# value 5 happened 1573 times
# value 6 happened 1548 times
# value 1 happened 1599 times
# value 2 happened 1564 times
# value 3 happened 1531 times
# value 4 happened 1519 times
# value 5 happened 1573 times
# value 6 happened 1549 times
# value 1 happened 1600 times
# value 2 happened 1564 times
# value 3 happened 1531 times
# value 4 happened 1519 times
# value 5 happened 1573 times
# value 6 happened 1549 times
# value 1 happened 1600 times
# value 2 happened 1564 times
# value 3 happened 1531 times
# value 4 happened 1519 times
# value 5 happened 1574 times
# value 6 happened 1549 times
# value 1 happened 1600 times
# value 2 happened 1564 times
# value 3 happened 1532 times
# value 4 happened 1519 times
# value 5 happened 1574 times
# value 6 happened 1549 times
# value 1 happened 1601 times
# value 2 happened 1564 times
# value 3 happened 1532 times
# value 4 happened 1519 times
# value 5 happened 1574 times
# value 6 happened 1549 times
# value 1 happened 1601 times
# value 2 happened 1564 times
# value 3 happened 1532 times
# value 4 happened 1520 times
# value 5 happened 1574 times
# value 6 happened 1549 times
# value 1 happened 1601 times
# value 2 happened 1564 times
# value 3 happened 1532 times
# value 4 happened 1521 times
# value 5 happened 1574 times
# value 6 happened 1549 times
# value 1 happened 1602 times
# value 2 happened 1564 times
# value 3 happened 1532 times
# value 4 happened 1521 times
# value 5 happened 1574 times
# value 6 happened 1549 times
# value 1 happened 1602 times
# value 2 happened 1564 times
# value 3 happened 1533 times
# value 4 happened 1521 times
# value 5 happened 1574 times
# value 6 happened 1549 times
# value 1 happened 1602 times
# value 2 happened 1564 times
# value 3 happened 1534 times
# value 4 happened 1521 times
# value 5 happened 1574 times
# value 6 happened 1549 times
# value 1 happened 1602 times
# value 2 happened 1565 times
# value 3 happened 1534 times
# value 4 happened 1521 times
# value 5 happened 1574 times
# value 6 happened 1549 times
# value 1 happened 1602 times
# value 2 happened 1566 times
# value 3 happened 1534 times
# value 4 happened 1521 times
# value 5 happened 1574 times
# value 6 happened 1549 times
# value 1 happened 1602 times
# value 2 happened 1566 times
# value 3 happened 1534 times
# value 4 happened 1521 times
# value 5 happened 1574 times
# value 6 happened 1550 times
# value 1 happened 1602 times
# value 2 happened 1566 times
# value 3 happened 1535 times
# value 4 happened 1521 times
# value 5 happened 1574 times
# value 6 happened 1550 times
# value 1 happened 1603 times
# value 2 happened 1566 times
# value 3 happened 1535 times
# value 4 happened 1521 times
# value 5 happened 1574 times
# value 6 happened 1550 times
# value 1 happened 1603 times
# value 2 happened 1566 times
# value 3 happened 1535 times
# value 4 happened 1522 times
# value 5 happened 1574 times
# value 6 happened 1550 times
# value 1 happened 1603 times
# value 2 happened 1567 times
# value 3 happened 1535 times
# value 4 happened 1522 times
# value 5 happened 1574 times
# value 6 happened 1550 times
# value 1 happened 1603 times
# value 2 happened 1567 times
# value 3 happened 1536 times
# value 4 happened 1522 times
# value 5 happened 1574 times
# value 6 happened 1550 times
# value 1 happened 1603 times
# value 2 happened 1567 times
# value 3 happened 1536 times
# value 4 happened 1523 times
# value 5 happened 1574 times
# value 6 happened 1550 times
# value 1 happened 1604 times
# value 2 happened 1567 times
# value 3 happened 1536 times
# value 4 happened 1523 times
# value 5 happened 1574 times
# value 6 happened 1550 times
# value 1 happened 1604 times
# value 2 happened 1568 times
# value 3 happened 1536 times
# value 4 happened 1523 times
# value 5 happened 1574 times
# value 6 happened 1550 times
# value 1 happened 1604 times
# value 2 happened 1568 times
# value 3 happened 1536 times
# value 4 happened 1524 times
# value 5 happened 1574 times
# value 6 happened 1550 times
# value 1 happened 1604 times
# value 2 happened 1568 times
# value 3 happened 1536 times
# value 4 happened 1524 times
# value 5 happened 1575 times
# value 6 happened 1550 times
# value 1 happened 1604 times
# value 2 happened 1568 times
# value 3 happened 1536 times
# value 4 happened 1524 times
# value 5 happened 1576 times
# value 6 happened 1550 times
# value 1 happened 1605 times
# value 2 happened 1568 times
# value 3 happened 1536 times
# value 4 happened 1524 times
# value 5 happened 1576 times
# value 6 happened 1550 times
# value 1 happened 1605 times
# value 2 happened 1568 times
# value 3 happened 1537 times
# value 4 happened 1524 times
# value 5 happened 1576 times
# value 6 happened 1550 times
# value 1 happened 1605 times
# value 2 happened 1568 times
# value 3 happened 1537 times
# value 4 happened 1524 times
# value 5 happened 1576 times
# value 6 happened 1551 times
# value 1 happened 1606 times
# value 2 happened 1568 times
# value 3 happened 1537 times
# value 4 happened 1524 times
# value 5 happened 1576 times
# value 6 happened 1551 times
# value 1 happened 1607 times
# value 2 happened 1568 times
# value 3 happened 1537 times
# value 4 happened 1524 times
# value 5 happened 1576 times
# value 6 happened 1551 times
# value 1 happened 1608 times
# value 2 happened 1568 times
# value 3 happened 1537 times
# value 4 happened 1524 times
# value 5 happened 1576 times
# value 6 happened 1551 times
# value 1 happened 1608 times
# value 2 happened 1569 times
# value 3 happened 1537 times
# value 4 happened 1524 times
# value 5 happened 1576 times
# value 6 happened 1551 times
# value 1 happened 1608 times
# value 2 happened 1569 times
# value 3 happened 1538 times
# value 4 happened 1524 times
# value 5 happened 1576 times
# value 6 happened 1551 times
# value 1 happened 1609 times
# value 2 happened 1569 times
# value 3 happened 1538 times
# value 4 happened 1524 times
# value 5 happened 1576 times
# value 6 happened 1551 times
# value 1 happened 1609 times
# value 2 happened 1569 times
# value 3 happened 1538 times
# value 4 happened 1525 times
# value 5 happened 1576 times
# value 6 happened 1551 times
# value 1 happened 1610 times
# value 2 happened 1569 times
# value 3 happened 1538 times
# value 4 happened 1525 times
# value 5 happened 1576 times
# value 6 happened 1551 times
# value 1 happened 1610 times
# value 2 happened 1569 times
# value 3 happened 1538 times
# value 4 happened 1526 times
# value 5 happened 1576 times
# value 6 happened 1551 times
# value 1 happened 1610 times
# value 2 happened 1569 times
# value 3 happened 1539 times
# value 4 happened 1526 times
# value 5 happened 1576 times
# value 6 happened 1551 times
# value 1 happened 1610 times
# value 2 happened 1569 times
# value 3 happened 1539 times
# value 4 happened 1526 times
# value 5 happened 1577 times
# value 6 happened 1551 times
# value 1 happened 1610 times
# value 2 happened 1569 times
# value 3 happened 1540 times
# value 4 happened 1526 times
# value 5 happened 1577 times
# value 6 happened 1551 times
# value 1 happened 1610 times
# value 2 happened 1569 times
# value 3 happened 1540 times
# value 4 happened 1527 times
# value 5 happened 1577 times
# value 6 happened 1551 times
# value 1 happened 1610 times
# value 2 happened 1570 times
# value 3 happened 1540 times
# value 4 happened 1527 times
# value 5 happened 1577 times
# value 6 happened 1551 times
# value 1 happened 1610 times
# value 2 happened 1571 times
# value 3 happened 1540 times
# value 4 happened 1527 times
# value 5 happened 1577 times
# value 6 happened 1551 times
# value 1 happened 1610 times
# value 2 happened 1571 times
# value 3 happened 1540 times
# value 4 happened 1527 times
# value 5 happened 1577 times
# value 6 happened 1552 times
# value 1 happened 1610 times
# value 2 happened 1571 times
# value 3 happened 1540 times
# value 4 happened 1527 times
# value 5 happened 1577 times
# value 6 happened 1553 times
# value 1 happened 1610 times
# value 2 happened 1571 times
# value 3 happened 1540 times
# value 4 happened 1527 times
# value 5 happened 1578 times
# value 6 happened 1553 times
# value 1 happened 1610 times
# value 2 happened 1571 times
# value 3 happened 1540 times
# value 4 happened 1527 times
# value 5 happened 1579 times
# value 6 happened 1553 times
# value 1 happened 1610 times
# value 2 happened 1571 times
# value 3 happened 1540 times
# value 4 happened 1528 times
# value 5 happened 1579 times
# value 6 happened 1553 times
# value 1 happened 1610 times
# value 2 happened 1571 times
# value 3 happened 1540 times
# value 4 happened 1529 times
# value 5 happened 1579 times
# value 6 happened 1553 times
# value 1 happened 1611 times
# value 2 happened 1571 times
# value 3 happened 1540 times
# value 4 happened 1529 times
# value 5 happened 1579 times
# value 6 happened 1553 times
# value 1 happened 1611 times
# value 2 happened 1571 times
# value 3 happened 1540 times
# value 4 happened 1530 times
# value 5 happened 1579 times
# value 6 happened 1553 times
# value 1 happened 1611 times
# value 2 happened 1572 times
# value 3 happened 1540 times
# value 4 happened 1530 times
# value 5 happened 1579 times
# value 6 happened 1553 times
# value 1 happened 1611 times
# value 2 happened 1572 times
# value 3 happened 1540 times
# value 4 happened 1531 times
# value 5 happened 1579 times
# value 6 happened 1553 times
# value 1 happened 1612 times
# value 2 happened 1572 times
# value 3 happened 1540 times
# value 4 happened 1531 times
# value 5 happened 1579 times
# value 6 happened 1553 times
# value 1 happened 1612 times
# value 2 happened 1572 times
# value 3 happened 1541 times
# value 4 happened 1531 times
# value 5 happened 1579 times
# value 6 happened 1553 times
# value 1 happened 1612 times
# value 2 happened 1573 times
# value 3 happened 1541 times
# value 4 happened 1531 times
# value 5 happened 1579 times
# value 6 happened 1553 times
# value 1 happened 1612 times
# value 2 happened 1573 times
# value 3 happened 1541 times
# value 4 happened 1531 times
# value 5 happened 1580 times
# value 6 happened 1553 times
# value 1 happened 1613 times
# value 2 happened 1573 times
# value 3 happened 1541 times
# value 4 happened 1531 times
# value 5 happened 1580 times
# value 6 happened 1553 times
# value 1 happened 1613 times
# value 2 happened 1574 times
# value 3 happened 1541 times
# value 4 happened 1531 times
# value 5 happened 1580 times
# value 6 happened 1553 times
# value 1 happened 1613 times
# value 2 happened 1574 times
# value 3 happened 1542 times
# value 4 happened 1531 times
# value 5 happened 1580 times
# value 6 happened 1553 times
# value 1 happened 1613 times
# value 2 happened 1574 times
# value 3 happened 1543 times
# value 4 happened 1531 times
# value 5 happened 1580 times
# value 6 happened 1553 times
# value 1 happened 1613 times
# value 2 happened 1574 times
# value 3 happened 1543 times
# value 4 happened 1531 times
# value 5 happened 1581 times
# value 6 happened 1553 times
# value 1 happened 1613 times
# value 2 happened 1574 times
# value 3 happened 1544 times
# value 4 happened 1531 times
# value 5 happened 1581 times
# value 6 happened 1553 times
# value 1 happened 1613 times
# value 2 happened 1575 times
# value 3 happened 1544 times
# value 4 happened 1531 times
# value 5 happened 1581 times
# value 6 happened 1553 times
# value 1 happened 1613 times
# value 2 happened 1575 times
# value 3 happened 1544 times
# value 4 happened 1532 times
# value 5 happened 1581 times
# value 6 happened 1553 times
# value 1 happened 1613 times
# value 2 happened 1576 times
# value 3 happened 1544 times
# value 4 happened 1532 times
# value 5 happened 1581 times
# value 6 happened 1553 times
# value 1 happened 1614 times
# value 2 happened 1576 times
# value 3 happened 1544 times
# value 4 happened 1532 times
# value 5 happened 1581 times
# value 6 happened 1553 times
# value 1 happened 1615 times
# value 2 happened 1576 times
# value 3 happened 1544 times
# value 4 happened 1532 times
# value 5 happened 1581 times
# value 6 happened 1553 times
# value 1 happened 1616 times
# value 2 happened 1576 times
# value 3 happened 1544 times
# value 4 happened 1532 times
# value 5 happened 1581 times
# value 6 happened 1553 times
# value 1 happened 1616 times
# value 2 happened 1576 times
# value 3 happened 1544 times
# value 4 happened 1532 times
# value 5 happened 1581 times
# value 6 happened 1554 times
# value 1 happened 1616 times
# value 2 happened 1576 times
# value 3 happened 1544 times
# value 4 happened 1533 times
# value 5 happened 1581 times
# value 6 happened 1554 times
# value 1 happened 1616 times
# value 2 happened 1576 times
# value 3 happened 1545 times
# value 4 happened 1533 times
# value 5 happened 1581 times
# value 6 happened 1554 times
# value 1 happened 1616 times
# value 2 happened 1576 times
# value 3 happened 1545 times
# value 4 happened 1533 times
# value 5 happened 1581 times
# value 6 happened 1555 times
# value 1 happened 1616 times
# value 2 happened 1576 times
# value 3 happened 1545 times
# value 4 happened 1533 times
# value 5 happened 1581 times
# value 6 happened 1556 times
# value 1 happened 1616 times
# value 2 happened 1576 times
# value 3 happened 1545 times
# value 4 happened 1533 times
# value 5 happened 1581 times
# value 6 happened 1557 times
# value 1 happened 1616 times
# value 2 happened 1576 times
# value 3 happened 1546 times
# value 4 happened 1533 times
# value 5 happened 1581 times
# value 6 happened 1557 times
# value 1 happened 1616 times
# value 2 happened 1576 times
# value 3 happened 1546 times
# value 4 happened 1533 times
# value 5 happened 1581 times
# value 6 happened 1558 times
# value 1 happened 1616 times
# value 2 happened 1576 times
# value 3 happened 1547 times
# value 4 happened 1533 times
# value 5 happened 1581 times
# value 6 happened 1558 times
# value 1 happened 1616 times
# value 2 happened 1576 times
# value 3 happened 1548 times
# value 4 happened 1533 times
# value 5 happened 1581 times
# value 6 happened 1558 times
# value 1 happened 1616 times
# value 2 happened 1576 times
# value 3 happened 1548 times
# value 4 happened 1533 times
# value 5 happened 1582 times
# value 6 happened 1558 times
# value 1 happened 1616 times
# value 2 happened 1576 times
# value 3 happened 1548 times
# value 4 happened 1534 times
# value 5 happened 1582 times
# value 6 happened 1558 times
# value 1 happened 1616 times
# value 2 happened 1577 times
# value 3 happened 1548 times
# value 4 happened 1534 times
# value 5 happened 1582 times
# value 6 happened 1558 times
# value 1 happened 1616 times
# value 2 happened 1577 times
# value 3 happened 1548 times
# value 4 happened 1534 times
# value 5 happened 1583 times
# value 6 happened 1558 times
# value 1 happened 1616 times
# value 2 happened 1577 times
# value 3 happened 1548 times
# value 4 happened 1535 times
# value 5 happened 1583 times
# value 6 happened 1558 times
# value 1 happened 1617 times
# value 2 happened 1577 times
# value 3 happened 1548 times
# value 4 happened 1535 times
# value 5 happened 1583 times
# value 6 happened 1558 times
# value 1 happened 1617 times
# value 2 happened 1578 times
# value 3 happened 1548 times
# value 4 happened 1535 times
# value 5 happened 1583 times
# value 6 happened 1558 times
# value 1 happened 1618 times
# value 2 happened 1578 times
# value 3 happened 1548 times
# value 4 happened 1535 times
# value 5 happened 1583 times
# value 6 happened 1558 times
# value 1 happened 1618 times
# value 2 happened 1578 times
# value 3 happened 1548 times
# value 4 happened 1536 times
# value 5 happened 1583 times
# value 6 happened 1558 times
# value 1 happened 1618 times
# value 2 happened 1578 times
# value 3 happened 1549 times
# value 4 happened 1536 times
# value 5 happened 1583 times
# value 6 happened 1558 times
# value 1 happened 1618 times
# value 2 happened 1578 times
# value 3 happened 1549 times
# value 4 happened 1536 times
# value 5 happened 1584 times
# value 6 happened 1558 times
# value 1 happened 1618 times
# value 2 happened 1578 times
# value 3 happened 1549 times
# value 4 happened 1536 times
# value 5 happened 1584 times
# value 6 happened 1559 times
# value 1 happened 1618 times
# value 2 happened 1578 times
# value 3 happened 1549 times
# value 4 happened 1536 times
# value 5 happened 1584 times
# value 6 happened 1560 times
# value 1 happened 1619 times
# value 2 happened 1578 times
# value 3 happened 1549 times
# value 4 happened 1536 times
# value 5 happened 1584 times
# value 6 happened 1560 times
# value 1 happened 1619 times
# value 2 happened 1578 times
# value 3 happened 1549 times
# value 4 happened 1536 times
# value 5 happened 1585 times
# value 6 happened 1560 times
# value 1 happened 1619 times
# value 2 happened 1579 times
# value 3 happened 1549 times
# value 4 happened 1536 times
# value 5 happened 1585 times
# value 6 happened 1560 times
# value 1 happened 1619 times
# value 2 happened 1579 times
# value 3 happened 1549 times
# value 4 happened 1536 times
# value 5 happened 1586 times
# value 6 happened 1560 times
# value 1 happened 1620 times
# value 2 happened 1579 times
# value 3 happened 1549 times
# value 4 happened 1536 times
# value 5 happened 1586 times
# value 6 happened 1560 times
# value 1 happened 1620 times
# value 2 happened 1579 times
# value 3 happened 1549 times
# value 4 happened 1536 times
# value 5 happened 1586 times
# value 6 happened 1561 times
# value 1 happened 1620 times
# value 2 happened 1579 times
# value 3 happened 1549 times
# value 4 happened 1536 times
# value 5 happened 1587 times
# value 6 happened 1561 times
# value 1 happened 1620 times
# value 2 happened 1579 times
# value 3 happened 1550 times
# value 4 happened 1536 times
# value 5 happened 1587 times
# value 6 happened 1561 times
# value 1 happened 1620 times
# value 2 happened 1580 times
# value 3 happened 1550 times
# value 4 happened 1536 times
# value 5 happened 1587 times
# value 6 happened 1561 times
# value 1 happened 1620 times
# value 2 happened 1580 times
# value 3 happened 1550 times
# value 4 happened 1537 times
# value 5 happened 1587 times
# value 6 happened 1561 times
# value 1 happened 1620 times
# value 2 happened 1580 times
# value 3 happened 1551 times
# value 4 happened 1537 times
# value 5 happened 1587 times
# value 6 happened 1561 times
# value 1 happened 1620 times
# value 2 happened 1580 times
# value 3 happened 1552 times
# value 4 happened 1537 times
# value 5 happened 1587 times
# value 6 happened 1561 times
# value 1 happened 1620 times
# value 2 happened 1580 times
# value 3 happened 1552 times
# value 4 happened 1538 times
# value 5 happened 1587 times
# value 6 happened 1561 times
# value 1 happened 1620 times
# value 2 happened 1580 times
# value 3 happened 1552 times
# value 4 happened 1538 times
# value 5 happened 1588 times
# value 6 happened 1561 times
# value 1 happened 1620 times
# value 2 happened 1580 times
# value 3 happened 1552 times
# value 4 happened 1539 times
# value 5 happened 1588 times
# value 6 happened 1561 times
# value 1 happened 1620 times
# value 2 happened 1580 times
# value 3 happened 1552 times
# value 4 happened 1540 times
# value 5 happened 1588 times
# value 6 happened 1561 times
# value 1 happened 1620 times
# value 2 happened 1580 times
# value 3 happened 1552 times
# value 4 happened 1540 times
# value 5 happened 1589 times
# value 6 happened 1561 times
# value 1 happened 1620 times
# value 2 happened 1580 times
# value 3 happened 1552 times
# value 4 happened 1541 times
# value 5 happened 1589 times
# value 6 happened 1561 times
# value 1 happened 1621 times
# value 2 happened 1580 times
# value 3 happened 1552 times
# value 4 happened 1541 times
# value 5 happened 1589 times
# value 6 happened 1561 times
# value 1 happened 1621 times
# value 2 happened 1581 times
# value 3 happened 1552 times
# value 4 happened 1541 times
# value 5 happened 1589 times
# value 6 happened 1561 times
# value 1 happened 1621 times
# value 2 happened 1581 times
# value 3 happened 1552 times
# value 4 happened 1541 times
# value 5 happened 1590 times
# value 6 happened 1561 times
# value 1 happened 1621 times
# value 2 happened 1581 times
# value 3 happened 1552 times
# value 4 happened 1541 times
# value 5 happened 1590 times
# value 6 happened 1562 times
# value 1 happened 1621 times
# value 2 happened 1582 times
# value 3 happened 1552 times
# value 4 happened 1541 times
# value 5 happened 1590 times
# value 6 happened 1562 times
# value 1 happened 1621 times
# value 2 happened 1582 times
# value 3 happened 1552 times
# value 4 happened 1541 times
# value 5 happened 1590 times
# value 6 happened 1563 times
# value 1 happened 1621 times
# value 2 happened 1582 times
# value 3 happened 1552 times
# value 4 happened 1542 times
# value 5 happened 1590 times
# value 6 happened 1563 times
# value 1 happened 1622 times
# value 2 happened 1582 times
# value 3 happened 1552 times
# value 4 happened 1542 times
# value 5 happened 1590 times
# value 6 happened 1563 times
# value 1 happened 1622 times
# value 2 happened 1582 times
# value 3 happened 1553 times
# value 4 happened 1542 times
# value 5 happened 1590 times
# value 6 happened 1563 times
# ...
# value 6 happened 1647 times
# value 1 happened 1703 times
# value 2 happened 1658 times
# value 3 happened 1626 times
# value 4 happened 1614 times
# value 5 happened 1658 times
# value 6 happened 1647 times
# value 1 happened 1703 times
# value 2 happened 1658 times
# value 3 happened 1626 times
# value 4 happened 1614 times
# value 5 happened 1658 times
# value 6 happened 1648 times
# value 1 happened 1703 times
# value 2 happened 1659 times
# value 3 happened 1626 times
# value 4 happened 1614 times
# value 5 happened 1658 times
# value 6 happened 1648 times
# value 1 happened 1703 times
# value 2 happened 1659 times
# value 3 happened 1626 times
# value 4 happened 1615 times
# value 5 happened 1658 times
# value 6 happened 1648 times
# value 1 happened 1703 times
# value 2 happened 1659 times
# value 3 happened 1626 times
# value 4 happened 1616 times
# value 5 happened 1658 times
# value 6 happened 1648 times
# value 1 happened 1703 times
# value 2 happened 1660 times
# value 3 happened 1626 times
# value 4 happened 1616 times
# value 5 happened 1658 times
# value 6 happened 1648 times
# value 1 happened 1703 times
# value 2 happened 1660 times
# value 3 happened 1626 times
# value 4 happened 1616 times
# value 5 happened 1658 times
# value 6 happened 1649 times
# value 1 happened 1703 times
# value 2 happened 1661 times
# value 3 happened 1626 times
# value 4 happened 1616 times
# value 5 happened 1658 times
# value 6 happened 1649 times
# value 1 happened 1703 times
# value 2 happened 1661 times
# value 3 happened 1626 times
# value 4 happened 1616 times
# value 5 happened 1658 times
# value 6 happened 1650 times
# value 1 happened 1703 times
# value 2 happened 1662 times
# value 3 happened 1626 times
# value 4 happened 1616 times
# value 5 happened 1658 times
# value 6 happened 1650 times
# value 1 happened 1703 times
# value 2 happened 1662 times
# value 3 happened 1627 times
# value 4 happened 1616 times
# value 5 happened 1658 times
# value 6 happened 1650 times
# value 1 happened 1703 times
# value 2 happened 1663 times
# value 3 happened 1627 times
# value 4 happened 1616 times
# value 5 happened 1658 times
# value 6 happened 1650 times
# value 1 happened 1703 times
# value 2 happened 1663 times
# value 3 happened 1627 times
# value 4 happened 1617 times
# value 5 happened 1658 times
# value 6 happened 1650 times
# value 1 happened 1703 times
# value 2 happened 1663 times
# value 3 happened 1627 times
# value 4 happened 1618 times
# value 5 happened 1658 times
# value 6 happened 1650 times
# value 1 happened 1703 times
# value 2 happened 1663 times
# value 3 happened 1628 times
# value 4 happened 1618 times
# value 5 happened 1658 times
# value 6 happened 1650 times
# value 1 happened 1703 times
# value 2 happened 1663 times
# value 3 happened 1628 times
# value 4 happened 1618 times
# value 5 happened 1659 times
# value 6 happened 1650 times
# value 1 happened 1703 times
# value 2 happened 1663 times
# value 3 happened 1628 times
# value 4 happened 1619 times
# value 5 happened 1659 times
# value 6 happened 1650 times
# value 1 happened 1703 times
# value 2 happened 1663 times
# value 3 happened 1628 times
# value 4 happened 1619 times
# value 5 happened 1660 times
# value 6 happened 1650 times
# value 1 happened 1704 times
# value 2 happened 1663 times
# value 3 happened 1628 times
# value 4 happened 1619 times
# value 5 happened 1660 times
# value 6 happened 1650 times
# value 1 happened 1704 times
# value 2 happened 1663 times
# value 3 happened 1628 times
# value 4 happened 1619 times
# value 5 happened 1660 times
# value 6 happened 1651 times
# value 1 happened 1704 times
# value 2 happened 1663 times
# value 3 happened 1628 times
# value 4 happened 1620 times
# value 5 happened 1660 times
# value 6 happened 1651 times
# value 1 happened 1704 times
# value 2 happened 1664 times
# value 3 happened 1628 times
# value 4 happened 1620 times
# value 5 happened 1660 times
# value 6 happened 1651 times
# value 1 happened 1704 times
# value 2 happened 1664 times
# value 3 happened 1628 times
# value 4 happened 1620 times
# value 5 happened 1661 times
# value 6 happened 1651 times
# value 1 happened 1704 times
# value 2 happened 1664 times
# value 3 happened 1628 times
# value 4 happened 1621 times
# value 5 happened 1661 times
# value 6 happened 1651 times
# value 1 happened 1704 times
# value 2 happened 1664 times
# value 3 happened 1629 times
# value 4 happened 1621 times
# value 5 happened 1661 times
# value 6 happened 1651 times
# value 1 happened 1704 times
# value 2 happened 1664 times
# value 3 happened 1629 times
# value 4 happened 1622 times
# value 5 happened 1661 times
# value 6 happened 1651 times
# value 1 happened 1705 times
# value 2 happened 1664 times
# value 3 happened 1629 times
# value 4 happened 1622 times
# value 5 happened 1661 times
# value 6 happened 1651 times
# value 1 happened 1706 times
# value 2 happened 1664 times
# value 3 happened 1629 times
# value 4 happened 1622 times
# value 5 happened 1661 times
# value 6 happened 1651 times
# value 1 happened 1706 times
# value 2 happened 1664 times
# value 3 happened 1629 times
# value 4 happened 1622 times
# value 5 happened 1661 times
# value 6 happened 1652 times
# value 1 happened 1706 times
# value 2 happened 1664 times
# value 3 happened 1629 times
# value 4 happened 1622 times
# value 5 happened 1662 times
# value 6 happened 1652 times
# value 1 happened 1706 times
# value 2 happened 1665 times
# value 3 happened 1629 times
# value 4 happened 1622 times
# value 5 happened 1662 times
# value 6 happened 1652 times
# value 1 happened 1706 times
# value 2 happened 1666 times
# value 3 happened 1629 times
# value 4 happened 1622 times
# value 5 happened 1662 times
# value 6 happened 1652 times
# value 1 happened 1706 times
# value 2 happened 1666 times
# value 3 happened 1629 times
# value 4 happened 1622 times
# value 5 happened 1663 times
# value 6 happened 1652 times
# value 1 happened 1706 times
# value 2 happened 1666 times
# value 3 happened 1629 times
# value 4 happened 1622 times
# value 5 happened 1663 times
# value 6 happened 1653 times
# value 1 happened 1706 times
# value 2 happened 1666 times
# value 3 happened 1629 times
# value 4 happened 1623 times
# value 5 happened 1663 times
# value 6 happened 1653 times
# value 1 happened 1706 times
# value 2 happened 1666 times
# value 3 happened 1629 times
# value 4 happened 1623 times
# value 5 happened 1663 times
# value 6 happened 1654 times
# value 1 happened 1706 times
# value 2 happened 1666 times
# value 3 happened 1629 times
# value 4 happened 1624 times
# value 5 happened 1663 times
# value 6 happened 1654 times
# value 1 happened 1706 times
# value 2 happened 1666 times
# value 3 happened 1630 times
# value 4 happened 1624 times
# value 5 happened 1663 times
# value 6 happened 1654 times
# value 1 happened 1706 times
# value 2 happened 1666 times
# value 3 happened 1630 times
# value 4 happened 1624 times
# value 5 happened 1664 times
# value 6 happened 1654 times
# value 1 happened 1707 times
# value 2 happened 1666 times
# value 3 happened 1630 times
# value 4 happened 1624 times
# value 5 happened 1664 times
# value 6 happened 1654 times
# value 1 happened 1707 times
# value 2 happened 1666 times
# value 3 happened 1630 times
# value 4 happened 1625 times
# value 5 happened 1664 times
# value 6 happened 1654 times
# value 1 happened 1707 times
# value 2 happened 1666 times
# value 3 happened 1631 times
# value 4 happened 1625 times
# value 5 happened 1664 times
# value 6 happened 1654 times
# value 1 happened 1707 times
# value 2 happened 1666 times
# value 3 happened 1631 times
# value 4 happened 1625 times
# value 5 happened 1665 times
# value 6 happened 1654 times
# value 1 happened 1707 times
# value 2 happened 1666 times
# value 3 happened 1631 times
# value 4 happened 1625 times
# value 5 happened 1665 times
# value 6 happened 1655 times
# value 1 happened 1707 times
# value 2 happened 1666 times
# value 3 happened 1631 times
# value 4 happened 1625 times
# value 5 happened 1665 times
# value 6 happened 1656 times
# value 1 happened 1707 times
# value 2 happened 1667 times
# value 3 happened 1631 times
# value 4 happened 1625 times
# value 5 happened 1665 times
# value 6 happened 1656 times
# value 1 happened 1707 times
# value 2 happened 1667 times
# value 3 happened 1632 times
# value 4 happened 1625 times
# value 5 happened 1665 times
# value 6 happened 1656 times
# value 1 happened 1707 times
# value 2 happened 1667 times
# value 3 happened 1632 times
# value 4 happened 1625 times
# value 5 happened 1666 times
# value 6 happened 1656 times
# value 1 happened 1707 times
# value 2 happened 1667 times
# value 3 happened 1632 times
# value 4 happened 1625 times
# value 5 happened 1666 times
# value 6 happened 1657 times
# value 1 happened 1707 times
# value 2 happened 1667 times
# value 3 happened 1632 times
# value 4 happened 1625 times
# value 5 happened 1667 times
# value 6 happened 1657 times
# value 1 happened 1708 times
# value 2 happened 1667 times
# value 3 happened 1632 times
# value 4 happened 1625 times
# value 5 happened 1667 times
# value 6 happened 1657 times
# value 1 happened 1708 times
# value 2 happened 1667 times
# value 3 happened 1633 times
# value 4 happened 1625 times
# value 5 happened 1667 times
# value 6 happened 1657 times
# value 1 happened 1708 times
# value 2 happened 1667 times
# value 3 happened 1633 times
# value 4 happened 1626 times
# value 5 happened 1667 times
# value 6 happened 1657 times
# value 1 happened 1709 times
# value 2 happened 1667 times
# value 3 happened 1633 times
# value 4 happened 1626 times
# value 5 happened 1667 times
# value 6 happened 1657 times
# value 1 happened 1709 times
# value 2 happened 1667 times
# value 3 happened 1634 times
# value 4 happened 1626 times
# value 5 happened 1667 times
# value 6 happened 1657 times
# value 1 happened 1709 times
# value 2 happened 1667 times
# value 3 happened 1634 times
# value 4 happened 1627 times
# value 5 happened 1667 times
# value 6 happened 1657 times
# value 1 happened 1709 times
# value 2 happened 1667 times
# value 3 happened 1634 times
# value 4 happened 1628 times
# value 5 happened 1667 times
# value 6 happened 1657 times
# value 1 happened 1709 times
# value 2 happened 1667 times
# value 3 happened 1635 times
# value 4 happened 1628 times
# value 5 happened 1667 times
# value 6 happened 1657 times
# value 1 happened 1709 times
# value 2 happened 1667 times
# value 3 happened 1635 times
# value 4 happened 1628 times
# value 5 happened 1667 times
# value 6 happened 1658 times
# value 1 happened 1709 times
# value 2 happened 1667 times
# value 3 happened 1635 times
# value 4 happened 1628 times
# value 5 happened 1668 times
# value 6 happened 1658 times
# value 1 happened 1709 times
# value 2 happened 1668 times
# value 3 happened 1635 times
# value 4 happened 1628 times
# value 5 happened 1668 times
# value 6 happened 1658 times
# value 1 happened 1709 times
# value 2 happened 1668 times
# value 3 happened 1635 times
# value 4 happened 1629 times
# value 5 happened 1668 times
# value 6 happened 1658 times
# value 1 happened 1709 times
# value 2 happened 1668 times
# value 3 happened 1635 times
# value 4 happened 1630 times
# value 5 happened 1668 times
# value 6 happened 1658 times
# value 1 happened 1709 times
# value 2 happened 1668 times
# value 3 happened 1635 times
# value 4 happened 1630 times
# value 5 happened 1669 times
# value 6 happened 1658 times
# value 1 happened 1710 times
# value 2 happened 1668 times
# value 3 happened 1635 times
# value 4 happened 1630 times
# value 5 happened 1669 times
# value 6 happened 1658 times
# value 1 happened 1710 times
# value 2 happened 1668 times
# value 3 happened 1636 times
# value 4 happened 1630 times
# value 5 happened 1669 times
# value 6 happened 1658 times
# value 1 happened 1710 times
# value 2 happened 1668 times
# value 3 happened 1637 times
# value 4 happened 1630 times
# value 5 happened 1669 times
# value 6 happened 1658 times
# value 1 happened 1710 times
# value 2 happened 1668 times
# value 3 happened 1637 times
# value 4 happened 1630 times
# value 5 happened 1670 times
# value 6 happened 1658 times
# value 1 happened 1710 times
# value 2 happened 1668 times
# value 3 happened 1638 times
# value 4 happened 1630 times
# value 5 happened 1670 times
# value 6 happened 1658 times
# value 1 happened 1710 times
# value 2 happened 1668 times
# value 3 happened 1638 times
# value 4 happened 1630 times
# value 5 happened 1670 times
# value 6 happened 1659 times
# value 1 happened 1711 times
# value 2 happened 1668 times
# value 3 happened 1638 times
# value 4 happened 1630 times
# value 5 happened 1670 times
# value 6 happened 1659 times
# value 1 happened 1711 times
# value 2 happened 1668 times
# value 3 happened 1639 times
# value 4 happened 1630 times
# value 5 happened 1670 times
# value 6 happened 1659 times
# value 1 happened 1711 times
# value 2 happened 1668 times
# value 3 happened 1640 times
# value 4 happened 1630 times
# value 5 happened 1670 times
# value 6 happened 1659 times
# value 1 happened 1711 times
# value 2 happened 1668 times
# value 3 happened 1640 times
# value 4 happened 1631 times
# value 5 happened 1670 times
# value 6 happened 1659 times
# value 1 happened 1711 times
# value 2 happened 1668 times
# value 3 happened 1640 times
# value 4 happened 1631 times
# value 5 happened 1670 times
# value 6 happened 1660 times
# value 1 happened 1711 times
# value 2 happened 1669 times
# value 3 happened 1640 times
# value 4 happened 1631 times
# value 5 happened 1670 times
# value 6 happened 1660 times
# value 1 happened 1711 times
# value 2 happened 1669 times
# value 3 happened 1640 times
# value 4 happened 1631 times
# value 5 happened 1670 times
# value 6 happened 1661 times
# value 1 happened 1711 times
# value 2 happened 1669 times
# value 3 happened 1640 times
# value 4 happened 1631 times
# value 5 happened 1671 times
# value 6 happened 1661 times
# value 1 happened 1711 times
# value 2 happened 1670 times
# value 3 happened 1640 times
# value 4 happened 1631 times
# value 5 happened 1671 times
# value 6 happened 1661 times
# value 1 happened 1711 times
# value 2 happened 1670 times
# value 3 happened 1640 times
# value 4 happened 1631 times
# value 5 happened 1672 times
# value 6 happened 1661 times
# value 1 happened 1711 times
# value 2 happened 1670 times
# value 3 happened 1641 times
# value 4 happened 1631 times
# value 5 happened 1672 times
# value 6 happened 1661 times
# value 1 happened 1711 times
# value 2 happened 1670 times
# value 3 happened 1641 times
# value 4 happened 1631 times
# value 5 happened 1672 times
# value 6 happened 1662 times
# value 1 happened 1711 times
# value 2 happened 1670 times
# value 3 happened 1641 times
# value 4 happened 1631 times
# value 5 happened 1673 times
# value 6 happened 1662 times
# value 1 happened 1711 times
# value 2 happened 1670 times
# value 3 happened 1642 times
# value 4 happened 1631 times
# value 5 happened 1673 times
# value 6 happened 1662 times
# value 1 happened 1711 times
# value 2 happened 1670 times
# value 3 happened 1642 times
# value 4 happened 1631 times
# value 5 happened 1673 times
# value 6 happened 1663 times
# value 1 happened 1711 times
# value 2 happened 1671 times
# value 3 happened 1642 times
# value 4 happened 1631 times
# value 5 happened 1673 times
# value 6 happened 1663 times
# value 1 happened 1711 times
# value 2 happened 1672 times
# value 3 happened 1642 times
# value 4 happened 1631 times
# value 5 happened 1673 times
# value 6 happened 1663 times
# value 1 happened 1711 times
# value 2 happened 1672 times
# value 3 happened 1642 times
# value 4 happened 1631 times
# value 5 happened 1674 times
# value 6 happened 1663 times
# value 1 happened 1712 times
# value 2 happened 1672 times
# value 3 happened 1642 times
# value 4 happened 1631 times
# value 5 happened 1674 times
# value 6 happened 1663 times
# value 1 happened 1712 times
# value 2 happened 1672 times
# value 3 happened 1643 times
# value 4 happened 1631 times
# value 5 happened 1674 times
# value 6 happened 1663 times
# value 1 happened 1712 times
# value 2 happened 1672 times
# value 3 happened 1643 times
# value 4 happened 1631 times
# value 5 happened 1674 times
# value 6 happened 1664 times
# value 1 happened 1712 times
# value 2 happened 1672 times
# value 3 happened 1643 times
# value 4 happened 1631 times
# value 5 happened 1675 times
# value 6 happened 1664 times
# value 1 happened 1712 times
# value 2 happened 1672 times
# value 3 happened 1643 times
# value 4 happened 1632 times
# value 5 happened 1675 times
# value 6 happened 1664 times
# value 1 happened 1712 times
# value 2 happened 1672 times
# value 3 happened 1643 times
# value 4 happened 1632 times
# value 5 happened 1675 times
# value 6 happened 1665 times
# value 1 happened 1712 times
# value 2 happened 1672 times
# value 3 happened 1643 times
# value 4 happened 1632 times
# value 5 happened 1675 times
# value 6 happened 1666 times
